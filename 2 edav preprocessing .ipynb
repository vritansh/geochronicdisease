# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.model_selection import cross_val_score, StratifiedKFold
from sklearn.preprocessing import StandardScaler
from sklearn.tree import DecisionTreeClassifier 
from sklearn import tree
from sklearn.metrics import accuracy_score
from sklearn.model_selection import cross_val_score
from sklearn.metrics import confusion_matrix
from sklearn import metrics
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.experimental import enable_hist_gradient_boosting
from sklearn.ensemble import HistGradientBoostingClassifier
from xgboost import XGBClassifier
# Out:
# /Users/ritvikkhandelwal/opt/anaconda3/lib/python3.9/site-packages/sklearn/experimental/enable_hist_gradient_boosting.py:16: UserWarning: Since version 1.0, it is not needed to import enable_hist_gradient_boosting anymore. HistGradientBoostingClassifier and HistGradientBoostingRegressor are now stable and can be normally imported from sklearn.ensemble.
#   warnings.warn(

# %%
df = pd.read_csv("CDC_update.csv")
df
# Out:
#         Unnamed: 0  YearStart  YearEnd LocationAbbr   LocationDesc DataSource  \
# 0                2       2018     2018           AK         Alaska       NVSS
# 1                6       2018     2018           AK         Alaska       NVSS
# 2               30       2018     2018           AL        Alabama       NVSS
# 3               44       2018     2018           AR       Arkansas       NVSS
# 4               56       2018     2018           AZ        Arizona       NVSS
# ...            ...        ...      ...          ...            ...        ...
# 242984     1082323       2020     2020           WA     Washington      BRFSS
# 242985     1082324       2020     2020           WV  West Virginia      BRFSS
# 242986     1082325       2020     2020           WY        Wyoming      BRFSS
# 242987     1082326       2020     2020           VT        Vermont      BRFSS
# 242988     1082327       2020     2020           WI      Wisconsin      BRFSS
#
#                                                   Topic  \
# 0                                               Alcohol
# 1                                Cardiovascular Disease
# 2                                Cardiovascular Disease
# 3                                Cardiovascular Disease
# 4                                Cardiovascular Disease
# ...                                                 ...
# 242984  Nutrition, Physical Activity, and Weight Status
# 242985            Chronic Obstructive Pulmonary Disease
# 242986            Chronic Obstructive Pulmonary Disease
# 242987                           Overarching Conditions
# 242988                                         Diabetes
#
#                                                  Question  \
# 0                         Chronic liver disease mortality
# 1            Mortality from total cardiovascular diseases
# 2                   Mortality from coronary heart disease
# 3                   Mortality from coronary heart disease
# 4            Mortality from total cardiovascular diseases
# ...                                                   ...
# 242984              Obesity among adults aged >= 18 years
# 242985  Prevalence of current smoking among adults >= ...
# 242986  Influenza vaccination among noninstitutionaliz...
# 242987  Self-rated health status among women aged 18-4...
# 242988  Prevalence of diagnosed diabetes among adults ...
#
#                   DataValueType StratificationCategory1  \
# 0                        Number                 Overall
# 1                    Crude Rate                 Overall
# 2                        Number                  Gender
# 3                        Number                  Gender
# 4                        Number          Race/Ethnicity
# ...                         ...                     ...
# 242984         Crude Prevalence          Race/Ethnicity
# 242985  Age-adjusted Prevalence          Race/Ethnicity
# 242986         Crude Prevalence          Race/Ethnicity
# 242987         Crude Prevalence          Race/Ethnicity
# 242988  Age-adjusted Prevalence          Race/Ethnicity
#
#                   Stratification1  \
# 0                         Overall
# 1                         Overall
# 2                            Male
# 3                          Female
# 4       Asian or Pacific Islander
# ...                           ...
# 242984        Black, non-Hispanic
# 242985        White, non-Hispanic
# 242986        White, non-Hispanic
# 242987        Other, non-Hispanic
# 242988  Multiracial, non-Hispanic
#
#                                            GeoLocation  LocationID TopicID  \
# 0        POINT (-147.72205903599973 64.84507995700051)           2     ALC
# 1        POINT (-147.72205903599973 64.84507995700051)           2     CVD
# 2         POINT (-86.63186076199969 32.84057112200048)           1     CVD
# 3         POINT (-92.27449074299966 34.74865012400045)           5     CVD
# 4       POINT (-111.76381127699972 34.865970280000454)           4     CVD
# ...                                                ...         ...     ...
# 242984   POINT (-120.47001078999972 47.52227862900048)          53    NPAW
# 242985    POINT (-80.71264013499967 38.66551020200046)          54    COPD
# 242986   POINT (-108.10983035299967 43.23554134300048)          56    COPD
# 242987    POINT (-72.51764079099962 43.62538123900049)          50     OVC
# 242988    POINT (-89.81637074199966 44.39319117400049)          55     DIA
#
#        QuestionID DataValueTypeID StratificationCategoryID1 StratificationID1
# 0          ALC6_0            NMBR                   OVERALL               OVR
# 1          CVD1_1         CRDRATE                   OVERALL               OVR
# 2          CVD1_3            NMBR                    GENDER              GENM
# 3          CVD1_3            NMBR                    GENDER              GENF
# 4          CVD1_1            NMBR                      RACE               API
# ...           ...             ...                       ...               ...
# 242984    NPAW1_1         CRDPREV                      RACE               BLK
# 242985  COPD3_0_1      AGEADJPREV                      RACE               WHT
# 242986    COPD7_0         CRDPREV                      RACE               WHT
# 242987     OVC6_2         CRDPREV                      RACE               OTH
# 242988     DIA2_1      AGEADJPREV                      RACE               MRC
#
# [242989 rows x 18 columns]
